# %%
import pandas as pd
import os

# %% [markdown]
# ### getting the file lists

# %%
# setting the data directory
data_dir = '../../AI_perception_survey_data/WE'

# %%
# getting all file names
all_files = os.listdir(data_dir)

# %%
all_files
# Out:
# ['Public Perception of Artificial Intelligence Technologies [UK].csv',
#  'Public Perception of Artificial Intelligence Technologies [Deutsche].csv',
#  'Pollfish_Survey_%C3%96ffentliche_Wahrnehmung_der_k%C3%BCnstlichen_Intelligenz_%5BDeutsche%5D_1979903.xlsx',
#  'Public Perception of Artificial Intelligence Technologies [intl_Ver].csv',
#  "Perception Publique des technologies de l'Intelligence Artificielle [FR].csv",
#  'gm_all.csv',
#  'Pollfish_Survey_Perception_Publique_des_technologies_de_l%27Intelligence_Artificielle_%5BFR%5D_1979900.xlsx']

# %%
# extracting the pollfish ones
pf_files = [file for file in all_files if file.split('_')[0] == 'Pollfish']

# %%
pf_files
# Out:
# ['Pollfish_Survey_%C3%96ffentliche_Wahrnehmung_der_k%C3%BCnstlichen_Intelligenz_%5BDeutsche%5D_1979903.xlsx',
#  'Pollfish_Survey_Perception_Publique_des_technologies_de_l%27Intelligence_Artificielle_%5BFR%5D_1979900.xlsx']

# %%
# loading all files in
pf_de = pd.read_excel(os.path.join(data_dir, pf_files[0]), sheet_name = 'Individuals')
pf_fr = pd.read_excel(os.path.join(data_dir, pf_files[1]), sheet_name = 'Individuals')

# %%
# taking a brief look
pf_fr.head()
# Out:
#            ID         Time Started        Time Finished Manufacturer       OS  \
# 0   467934861  2019-05-17 08:12:35  2019-05-17 08:17:29      OnePlus  Android
# 1 -1953996334  2019-05-17 08:25:55  2019-05-17 08:27:54       Huawei  Android
# 2   873807755  2019-05-17 08:16:32  2019-05-17 08:22:48      Unknown  Android
# 3 -1008838748  2019-05-17 08:22:18  2019-05-17 08:26:14      Unknown      Web
# 4  -920061686  2019-05-17 08:12:58  2019-05-17 08:14:22      Unknown      iOS
#
#   Country                Area           City  Provider  Gender     ...       \
# 0      FR            Brittany  Miniac-Morvan  Bouygues    male     ...
# 1      FR       Île-de-France          Paris  Bouygues    male     ...
# 2      FR  Nouvelle-Aquitaine           Agen       SFR    male     ...
# 3      FR       Île-de-France          Paris       NaN  female     ...
# 4      BE            Flanders          Ghent       NaN    male     ...
#
#   Gamer  Value Shopper Food and Dining Lover Entertainment Enthusiast  \
# 0  True           True                  True                     True
# 1  True           True                  True                     True
# 2   NaN            NaN                   NaN                      NaN
# 3   NaN            NaN                   NaN                      NaN
# 4   NaN            NaN                   NaN                      NaN
#
#   Fashionista  Job Seeker  Insurance  Real Estate  Car Purchase  Unnamed: 65
# 0       False         NaN        NaN          NaN           NaN          NaN
# 1        True         NaN        NaN          NaN           NaN          NaN
# 2         NaN         NaN        NaN          NaN           NaN          NaN
# 3         NaN         NaN        NaN          NaN           NaN          NaN
# 4         NaN         NaN        NaN          NaN           NaN          NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# We have a lot of extra cols that might be interesting in other cases but for reason of uniformity we'll not need them for this analysis

# %% [markdown]
# ### cleaning, renaming and reordering columns

# %%
# seeing which cols to keep
for i, col in enumerate(pf_fr.columns):
    print('*******************', i, '*******************')
    print(col)
    print(' ')
# Out:
# ******************* 0 *******************
# ID
#
# ******************* 1 *******************
# Time Started
#
# ******************* 2 *******************
# Time Finished
#
# ******************* 3 *******************
# Manufacturer
#
# ******************* 4 *******************
# OS
#
# ******************* 5 *******************
# Country
#
# ******************* 6 *******************
# Area
#
# ******************* 7 *******************
# City
#
# ******************* 8 *******************
# Provider
#
# ******************* 9 *******************
# Gender
#
# ******************* 10 *******************
# Age
#
# ******************* 11 *******************
# Year Of Birth
#
# ******************* 12 *******************
# Comment évalueriez-vous votre connaissance personnelle des technologies d'intelligence artificielle ?
#
# ******************* 13 *******************
# Parmi les affirmations suivantes, lesquelles sont * fausses * concernant la nature ou les capacités de l'intelligence artificielle ?
#
# ******************* 14 *******************
# Avez-vous été servi par ou utilisé des technologies d'intelligence artificielle ?
#
# ******************* 15 *******************
# Sur une échelle de 1 à 7, comment évalueriez-vous l’impact des technologies de l’intelligence artificielle sur la SOCIÉTÉ [AUJOURD'HUI] ?
#
# ******************* 16 *******************
# Et dans les 10 prochaines années?
#
# ******************* 17 *******************
# Sur une échelle de 1 à 7, comment évalueriez-vous L'AMPLITUDE de l'impact de l'IA [AUJOURD'HUI]?
#
# ******************* 18 *******************
# Et dans les 10 prochaines années?.1
#
# ******************* 19 *******************
# Sur une échelle de 1 à 7, comment évalueriez-vous l'impact actuel de l'intelligence artificielle sur le travail pour vous?
#
# ******************* 20 *******************
# Et dans les 10 prochaines années?.2
#
# ******************* 21 *******************
# Selon vous, dans votre vie professionnelle, quels bénéfices technologiques seront permis par l'intelligence artificielle ? Merci de spécifier si d'autres
#
# ******************* 22 *******************
# Selon vous, dans votre vie professionnelle, quels aspects souffriront le plus des technologies de l'intelligence artificielle? Merci de spécifier si d'autres
#
# ******************* 23 *******************
# Sur une échelle de 1 à 7, comment évalueriez-vous l’impact actuel de l’intelligence artificielle sur votre vie personnelle?
#
# ******************* 24 *******************
# Et dans les 10 prochaines années
#
# ******************* 25 *******************
# Parmi les suivants, quels aspects de votre vie personnelle bénéficieront le plus de l'IA ? Merci de spécifier si d'autres
#
# ******************* 26 *******************
# Parmi les suivants, quels aspects de votre vie personnelle souffriront le plus de l'IA ? Merci de spécifier si d'autres
#
# ******************* 27 *******************
# Avec lequel des énoncés suivants êtes-vous le plus d'accord?
#
# ******************* 28 *******************
# Pensez-vous que vous risquez d'être remplacé par une intelligence artificielle?
#
# ******************* 29 *******************
# Veuillez sélectionner 3 emplois dans la liste ci-dessous qui, selon vous, risquent d'être remplacés par des applications d'Intelligence Artificielle dans les 10 prochaines années
#
# ******************* 30 *******************
# Parmi les aspects suivants, quelles caractéristiques rendent un emploi remplaçable par l'IA? Si d'autres, veuillez préciser
#
# ******************* 31 *******************
# Faites-vous confiance aux applications d'intelligence artificielle?
#
# ******************* 32 *******************
# Lesquels des facteurs suivants correspond le mieux à vos raisons de méfiance? si d'autres, veuillez spécifier
#
# ******************* 33 *******************
# Quelle est votre profession / domaine d’expertise (étudiant en histoire d'art,  pathologue, ingénieur métallurgique, mécanicienne, etc.)?
#
# ******************* 34 *******************
# Quelle est votre plus haute qualification en éducation?
#
# ******************* 35 *******************
# Possédez-vous un smart phone?
#
# ******************* 36 *******************
# Sur une échelle de 1 à 7, comment sera la vie dans 10 ans?
#
# ******************* 37 *******************
# Marital Status
#
# ******************* 38 *******************
# Number of children
#
# ******************* 39 *******************
# Education
#
# ******************* 40 *******************
# Employment Status
#
# ******************* 41 *******************
# Career
#
# ******************* 42 *******************
# Race
#
# ******************* 43 *******************
# Income
#
# ******************* 44 *******************
# Postal Code
#
# ******************* 45 *******************
# US Census Region
#
# ******************* 46 *******************
# US Census Division
#
# ******************* 47 *******************
# US Congressional District
#
# ******************* 48 *******************
# DMA Code
#
# ******************* 49 *******************
# DMA Name
#
# ******************* 50 *******************
# Musicfan
#
# ******************* 51 *******************
# Productivity Booster
#
# ******************* 52 *******************
# Bookworm
#
# ******************* 53 *******************
# Socialite
#
# ******************* 54 *******************
# Traveler
#
# ******************* 55 *******************
# Sportsfan
#
# ******************* 56 *******************
# Gamer
#
# ******************* 57 *******************
# Value Shopper
#
# ******************* 58 *******************
# Food and Dining Lover
#
# ******************* 59 *******************
# Entertainment Enthusiast
#
# ******************* 60 *******************
# Fashionista
#
# ******************* 61 *******************
# Job Seeker
#
# ******************* 62 *******************
# Insurance
#
# ******************* 63 *******************
# Real Estate
#
# ******************* 64 *******************
# Car Purchase
#
# ******************* 65 *******************
# Unnamed: 65

# %%
# selecting which cols to keep
cols_to_keep_fr = list(pf_fr.columns[12:37]) + [pf_fr.columns[5]] + [pf_fr.columns[10]] + [pf_fr.columns[39]]
cols_to_keep_de = list(pf_de.columns[12:37]) + [pf_de.columns[5]] + [pf_de.columns[10]] + [pf_fr.columns[39]]

# %%
# slimming the dfs down
pf_fr = pf_fr[cols_to_keep_fr]
pf_de = pf_de[cols_to_keep_de]

# %%
# new col names
cols_renamed = ['q{:02}'.format(i+1) for i in range(21)] + ['q{:02}'.format(i) for i in range(26,30)] + ['q25', 'q24_sup', 'q27_sup']

# %%
# renaming cols
pf_fr.columns = cols_renamed
pf_de.columns = cols_renamed

# %% [markdown]
# ### recoding answers

# %%
pf_fr.head(3)
# Out:
#                                                  q01  \
# 0                    J'en sais beaucoup sur le sujet
# 1                    J'en sais beaucoup sur le sujet
# 2  J'en ai entendu parler mais je ne suis pas sur...
#
#                                                  q02        q03  q04  q05  \
# 0  L’architecture du réseau neuronal récurrent ri...        Oui    5    6
# 1  L’IA peut rédiger des articles de qualité huma...        Oui    7    7
# 2  L'IA n'est capable d'effectuer qu'une gamme li...  Peut-être    4    6
#
#    q06  q07  q08  q09                                                q10  \
# 0    5    7    5    7  Nouvelles opportunités commerciales | Meilleur...
# 1    6    7    7    7  Nouvelles opportunités commerciales | Augmenta...
# 2    4    6    4    6                                              aucun
#
#                ...               \
# 0              ...
# 1              ...
# 2              ...
#
#                                                  q19        q20  \
# 0  Les compétences requises pour le travail sont ...        Oui
# 1  Les compétences requises pour le travail sont ...        Oui
# 2                               Manque de créativité  Peut-être
#
#                                                  q21                      q26  \
# 0  L'incapacité de l'IA à comprendre les nuances ...  Ingénieur métallurgique
# 1  L'incapacité de l'IA à comprendre les nuances ...                Ingénieur
# 2  L'IA peut être biaisée et renforcer l'injustic...          Sans profession
#
#                                             q27  q28 q29 q25  q24_sup  \
# 0                    Bachelor/BTS ou équivalent  Oui   6  FR  18 - 24
# 1         Doctorat, son équivalent ou supérieur  Oui   7  FR  18 - 24
# 2  Diplôme d'études secondaires ou l'équivalent  Oui   5  FR  45 - 54
#
#                         q27_sup
# 0                   high_school
# 1                   high_school
# 2  vocational_technical_college
#
# [3 rows x 28 columns]

# %% [markdown]
# The seperators are '|', whereas our recoding function uses ';' as the default seperator, we need to replace

# %%
# noting question numbers that need recoding

# multiple choice
q_num_mc = [2,10,11,14,15,18,19,21,24]
q_num_mc = ['q{:02}'.format(num) for num in q_num_mc]
# single choice
q_num_sc = [1,3,16,17,20,22,23,25,27,28]
q_num_sc = ['q{:02}'.format(num) for num in q_num_sc]
# all
q_num_all = q_num_mc + q_num_sc

# %%
# replacing '|' with ';'
for q_num in q_num_mc:
    if q_num in pf_fr.columns:
        pf_fr[q_num] = [ans.replace(' | ', ';') for ans in pf_fr[q_num]]
        pf_de[q_num] = [ans.replace(' | ', ';') for ans in pf_de[q_num]]

# %% [markdown]
# ### recoding

# %%
# importing the recoding function
from clean_functions import recode_answers

# regrouping the dataframes
all_pf = [pf_fr, pf_de]

# %%
# creating a list of lang variables
langs = ['fr', 'de']

# looping through all datasets
for i, dataset in enumerate(all_pf):
    # setting the right lang var
    lang = langs[i]
    
    # looping through all single choice questions
    for q_num in q_num_sc:
        # skipping questions that are missing
        if q_num in pf_fr.columns:
            # recode and replace
            dataset[q_num] = recode_answers(dataset, q_num, lang, False)
    
    # looping through all multiple choice questions
    for q_num in q_num_mc:
        # skipping questions that are missing
        if q_num in pf_fr.columns:
            # recode and replace
            dataset[q_num] = recode_answers(dataset, q_num, lang, True)

# %%
# inspecting the recoding results

cols = ['q{:02}'.format(i+1) for i in range(0,10)]
indices = list(range(30,60))

pf_fr.loc[indices, cols]
# Out:
#    q01                                                q02 q03  q04  q05  q06  \
# 30   C  [I, L’IA peut rédiger des articles de qualité ...   B    6    7    5
# 31   C                                             [G, D]   B    7    7    7
# 32   C                                          [G, E, D]   C    4    4    3
# 33   C                                                [C]   A    6    6    6
# 34   D                                       [I, G, D, B]   A    4    4    4
# 35   D                                          [I, D, B]   A    6    7    7
# 36   B                                             [E, A]   C    6    6    6
# 37   C                                             [F, A]   B    3    2    6
# 38   C                                             [B, A]   B    4    4    5
# 39   C                                          [I, G, B]   C    5    6    3
# 40   C  [I, L’IA peut rédiger des articles de qualité ...   B    7    7    7
# 41   B                                                [B]   C    5    5    5
# 42   B  [L’IA peut rédiger des articles de qualité hum...   B    4    5    3
# 43   D  [L’IA peut rédiger des articles de qualité hum...   A    3    5    5
# 44   C                                          [I, G, B]   B    4    5    4
# 45   C                                             [E, C]   B    3    5    3
# 46   D                                          [E, C, A]   A    6    4    7
# 47   E                                          [D, C, B]   A    7    7    5
# 48   C                                                [D]   B    5    6    5
# 49   D                                                [E]   B    4    4    4
# 50   D                                          [I, D, B]   A    4    6    5
# 51   D                                          [I, D, B]   A    5    6    5
# 52   B                                                [A]   B    2    2    3
# 53   E                                             [E, A]   A    7    6    6
# 54   C                                             [G, B]   A    6    6    6
# 55   D  [L’IA peut rédiger des articles de qualité hum...   A    6    5    5
# 56   C                                                [C]   A    6    6    6
# 57   B                                          [I, B, A]   B    5    6    4
# 58   D                                                [A]   B    4    3    3
# 59   B                                             [I, D]   B    4    5    2
#
#     q07  q08  q09        q10
# 30    6    4    7  [C, B, A]
# 31    7    7    7  [C, B, A]
# 32    5    4    4     [B, A]
# 33    6    6    6        [B]
# 34    4    4    4        [B]
# 35    6    7    6     [C, A]
# 36    6    6    6  [D, B, A]
# 37    6    4    4        [E]
# 38    4    4    4        [E]
# 39    6    4    5  [D, C, A]
# 40    7    7    7     [D, A]
# 41    5    5    6     [B, A]
# 42    5    3    5     [B, A]
# 43    6    3    3        [D]
# 44    5    3    3  [D, B, A]
# 45    6    2    5  [D, C, B]
# 46    5    5    5     [D, B]
# 47    6    4    4     [B, A]
# 48    6    4    5        [C]
# 49    4    5    4        [D]
# 50    7    3    2        [B]
# 51    6    2    5        [B]
# 52    2    3    3        [E]
# 53    6    6    7     [C, A]
# 54    6    6    7     [D, B]
# 55    6    6    6     [C, A]
# 56    5    6    5        [A]
# 57    7    3    4        [E]
# 58    5    5    3        [A]
# 59    5    3    1  [C, B, A]

# %% [markdown]
# Problems we've detected:
# 1. q02 --> one answer not properly coded

# %%
pf_fr.q02[1], pf_de.q02[1]
# Out:
# (['L’IA peut rédiger des articles de qualité humaine avec un thème clair, une grammaire correcte et un',
#   'G',
#   'F',
#   'E',
#   'A'],
#  ['KI bleibt ausschließlich in der akademischen Forschung und kann noch nicht kommerziell genutzt werde'])

# %% [markdown]
# Clearly PF cut the end of the answer off probably due to its length, we mannually replace

# %%
# reecode by hand
to_recode_fr = {pf_fr.q02[1][0]: 'H'}
to_recode_de = {pf_de.q02[1][0]:'B',
'KI kann menschenähnlich Artikel mit einem klaren Thema mit korrekter Grammatik und fortgeschrittenem': 'H',
'Die Architektur eines Recurrent Neural Network wird wahrscheinlich weiterhin an Popularität verliere': 'I'}
pf_fr.q02 = [[to_recode_fr[an] if an in to_recode_fr.keys() else an for an in ans] for ans in pf_fr.q02]
pf_de.q02 = [[to_recode_de[an] if an in to_recode_de.keys() else an for an in ans] for ans in pf_de.q02]

# %%
pf_fr.head()
# Out:
#   q01                 q02 q03  q04  q05  q06  q07  q08  q09        q10  \
# 0   D  [I, G, F, E, D, C]   A    5    6    5    7    5    7  [D, C, A]
# 1   D     [H, G, F, E, A]   A    7    7    6    7    7    7     [D, A]
# 2   B              [D, B]   C    4    6    4    6    4    6        [E]
# 3   C              [G, B]   C    4    3    6    7    4    5  [D, C, A]
# 4   A              [J, C]   C    5    4    5    3    5    6     [D, B]
#
#                ...                  q19  q20              q21  \
# 0              ...               [D, B]    A        [D, B, A]
# 1              ...               [D, A]    A        [D, C, A]
# 2              ...                  [E]    C              [C]
# 3              ...                  [B]    C  [E, D, C, B, A]
# 4              ...               [D, C]    C           [D, C]
#
#                         q26 q27 q28 q29 q25  q24_sup  \
# 0   Ingénieur métallurgique   B   A   6  FR  18 - 24
# 1                 Ingénieur   D   A   7  FR  18 - 24
# 2           Sans profession   A   A   5  FR  45 - 54
# 3  Etudiante en journalisme   B   A   4  FR  18 - 24
# 4                      Bobo   A   A   6  BE  18 - 24
#
#                         q27_sup
# 0                   high_school
# 1                   high_school
# 2  vocational_technical_college
# 3                   high_school
# 4                           NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# ### filling in empty columns and concat
# let's take a look at the col names

# %%
pf_fr.columns
# Out:
# Index(['q01', 'q02', 'q03', 'q04', 'q05', 'q06', 'q07', 'q08', 'q09', 'q10',
#        'q11', 'q12', 'q13', 'q14', 'q15', 'q16', 'q17', 'q18', 'q19', 'q20',
#        'q21', 'q26', 'q27', 'q28', 'q29', 'q25', 'q24_sup', 'q27_sup'],
#       dtype='object')

# %%
pf_de.columns
# Out:
# Index(['q01', 'q02', 'q03', 'q04', 'q05', 'q06', 'q07', 'q08', 'q09', 'q10',
#        'q11', 'q12', 'q13', 'q14', 'q15', 'q16', 'q17', 'q18', 'q19', 'q20',
#        'q21', 'q26', 'q27', 'q28', 'q29', 'q25', 'q24_sup', 'q27_sup'],
#       dtype='object')

# %%
# the empty cols
to_placehold = [22,23,24]
placeholder_cols = ['q{:02}'.format(i) for i in to_placehold]

# %%
# create empty cols
for col in placeholder_cols:
    pf_fr[col] = ['' for _ in range(len(pf_fr))]
    pf_de[col] = ['' for _ in range(len(pf_de))]

# %% [markdown]
# Let's recode q27_sup to combine it with q27

# %%
# setting up recoding mechanism with a dict
q27_sup_opts = list(set(pf_de.q27_sup))

# %%
# recoding dict
recode_vars = ['A', 'E', 'B', 'C', 'A']
q27_sup_opts = {q27_sup_opts[i]:recode_vars[i] for i in range(len(q27_sup_opts))}

# %%
# recode fr
pf_fr.q27_sup = [q27_sup_opts[ans] if ans in q27_sup_opts.keys() else ans for ans in pf_fr.q27_sup]

# %%
# recode de
pf_de.q27_sup = [q27_sup_opts[ans] if ans in q27_sup_opts.keys() else ans for ans in pf_de.q27_sup]

# %% [markdown]
# Now let's see how q27 and q27_sup match up against each other

# %%
# comparing q27 & sup
match_q27_fr = [pf_fr.q27[i] == pf_fr.q27_sup[i] for i in range(len(pf_fr))]
match_q27_de = [pf_de.q27[i] == pf_de.q27_sup[i] for i in range(len(pf_fr))]

# %%
# percentage of perfect matching
sum(match_q27_fr)/len(match_q27_fr), sum(match_q27_de)/len(match_q27_de)
# Out:
# (0.28, 0.28)

# %%
# let's take a look at those who don't match
for i in range(len(pf_fr)):
    print('*******', i, '*******')
    print(pf_fr.q27[i])
    print(pf_fr.q27_sup[i])
    print(' ')
# Out:
# ******* 0 *******
# B
# A
#
# ******* 1 *******
# D
# A
#
# ******* 2 *******
# A
# E
#
# ******* 3 *******
# B
# A
#
# ******* 4 *******
# A
# nan
#
# ******* 5 *******
# B
# E
#
# ******* 6 *******
# E
# B
#
# ******* 7 *******
# B
# B
#
# ******* 8 *******
# B
# A
#
# ******* 9 *******
# A
# A
#
# ******* 10 *******
# A
# E
#
# ******* 11 *******
# A
# B
#
# ******* 12 *******
# B
# C
#
# ******* 13 *******
# C
# B
#
# ******* 14 *******
# C
# A
#
# ******* 15 *******
# A
# E
#
# ******* 16 *******
# B
# B
#
# ******* 17 *******
# C
# nan
#
# ******* 18 *******
# A
# E
#
# ******* 19 *******
# D
# A
#
# ******* 20 *******
# A
# nan
#
# ******* 21 *******
# A
# C
#
# ******* 22 *******
# A
# E
#
# ******* 23 *******
# B
# B
#
# ******* 24 *******
# B
# B
#
# ******* 25 *******
# B
# A
#
# ******* 26 *******
# A
# E
#
# ******* 27 *******
# B
# B
#
# ******* 28 *******
# C
# B
#
# ******* 29 *******
# A
# E
#
# ******* 30 *******
# B
# B
#
# ******* 31 *******
# B
# A
#
# ******* 32 *******
# C
# B
#
# ******* 33 *******
# D
# A
#
# ******* 34 *******
# D
# A
#
# ******* 35 *******
# B
# B
#
# ******* 36 *******
# B
# E
#
# ******* 37 *******
# B
# B
#
# ******* 38 *******
# C
# B
#
# ******* 39 *******
# B
# B
#
# ******* 40 *******
# A
# B
#
# ******* 41 *******
# C
# B
#
# ******* 42 *******
# B
# nan
#
# ******* 43 *******
# C
# nan
#
# ******* 44 *******
# E
# B
#
# ******* 45 *******
# A
# A
#
# ******* 46 *******
# A
# A
#
# ******* 47 *******
# C
# nan
#
# ******* 48 *******
# A
# nan
#
# ******* 49 *******
# B
# nan
#
# ******* 50 *******
# E
# A
#
# ******* 51 *******
# A
# A
#
# ******* 52 *******
# Rien
# A
#
# ******* 53 *******
# C
# B
#
# ******* 54 *******
# C
# nan
#
# ******* 55 *******
# C
# A
#
# ******* 56 *******
# A
# A
#
# ******* 57 *******
# A
# A
#
# ******* 58 *******
# C
# B
#
# ******* 59 *******
# B
# B
#
# ******* 60 *******
# A
# E
#
# ******* 61 *******
# D
# B
#
# ******* 62 *******
# B
# A
#
# ******* 63 *******
# A
# A
#
# ******* 64 *******
# bepc
# A
#
# ******* 65 *******
# B
# nan
#
# ******* 66 *******
# A
# A
#
# ******* 67 *******
# A
# E
#
# ******* 68 *******
# A
# A
#
# ******* 69 *******
# C
# B
#
# ******* 70 *******
# B
# A
#
# ******* 71 *******
# B
# nan
#
# ******* 72 *******
# E
# E
#
# ******* 73 *******
# A
# nan
#
# ******* 74 *******
# A
# nan
#
# ******* 75 *******
# A
# nan
#
# ******* 76 *******
# E
# nan
#
# ******* 77 *******
# A
# A
#
# ******* 78 *******
# B
# B
#
# ******* 79 *******
# B
# A
#
# ******* 80 *******
# B
# B
#
# ******* 81 *******
# A
# E
#
# ******* 82 *******
# Dfeo
# E
#
# ******* 83 *******
# B
# A
#
# ******* 84 *******
# B
# B
#
# ******* 85 *******
# C
# B
#
# ******* 86 *******
# B
# B
#
# ******* 87 *******
# B
# B
#
# ******* 88 *******
# B
# B
#
# ******* 89 *******
# B
# B
#
# ******* 90 *******
# Cap
# C
#
# ******* 91 *******
# C
# E
#
# ******* 92 *******
# B
# A
#
# ******* 93 *******
# C
# B
#
# ******* 94 *******
# A
# nan
#
# ******* 95 *******
# C
# B
#
# ******* 96 *******
# B
# A
#
# ******* 97 *******
# C
# B
#
# ******* 98 *******
# B
# E
#
# ******* 99 *******
# B
# E

# %%
# let's take a look at those who don't match
for i in range(len(pf_de)):
    print('*******', i, '*******')
    print(pf_de.q27[i])
    print(pf_de.q27_sup[i])
    print(' ')
# Out:
# ******* 0 *******
# A
# E
#
# ******* 1 *******
# Realabschluss
# E
#
# ******* 2 *******
# A
# A
#
# ******* 3 *******
# realschule
# C
#
# ******* 4 *******
# A
# A
#
# ******* 5 *******
# A
# A
#
# ******* 6 *******
# A
# A
#
# ******* 7 *******
# E
# C
#
# ******* 8 *******
# A
# A
#
# ******* 9 *******
# Realschule
# C
#
# ******* 10 *******
# E
# C
#
# ******* 11 *******
# A
# A
#
# ******* 12 *******
# MSA
# C
#
# ******* 13 *******
# A
# A
#
# ******* 14 *******
# berufsausbildung
# A
#
# ******* 15 *******
# Hauptschule
# E
#
# ******* 16 *******
# A
# A
#
# ******* 17 *******
# C
# B
#
# ******* 18 *******
# A
# A
#
# ******* 19 *******
# E
# B
#
# ******* 20 *******
# A
# A
#
# ******* 21 *******
# Hauptschulabschluss
# C
#
# ******* 22 *******
# E
# E
#
# ******* 23 *******
# A
# C
#
# ******* 24 *******
# Realschule
# C
#
# ******* 25 *******
# E
# C
#
# ******* 26 *******
# B
# E
#
# ******* 27 *******
# Mittlere Reife
# C
#
# ******* 28 *******
# A
# A
#
# ******* 29 *******
# Fachschule
# C
#
# ******* 30 *******
# A
# A
#
# ******* 31 *******
# Mittlere Reife
# E
#
# ******* 32 *******
# C
# B
#
# ******* 33 *******
# E
# B
#
# ******* 34 *******
# A
# C
#
# ******* 35 *******
# B
# C
#
# ******* 36 *******
# Fachabitur
# E
#
# ******* 37 *******
# Lehre
# E
#
# ******* 38 *******
# A
# C
#
# ******* 39 *******
# A
# C
#
# ******* 40 *******
# C
# B
#
# ******* 41 *******
# C
# B
#
# ******* 42 *******
# B
# B
#
# ******* 43 *******
# A
# A
#
# ******* 44 *******
# B
# C
#
# ******* 45 *******
# B
# B
#
# ******* 46 *******
# C
# E
#
# ******* 47 *******
# Berufsabschluss
# C
#
# ******* 48 *******
# A
# E
#
# ******* 49 *******
# A
# A
#
# ******* 50 *******
# E
# E
#
# ******* 51 *******
# A
# C
#
# ******* 52 *******
# B
# B
#
# ******* 53 *******
# hauptschule
# C
#
# ******* 54 *******
# A
# E
#
# ******* 55 *******
# A
# A
#
# ******* 56 *******
# C
# A
#
# ******* 57 *******
# B
# B
#
# ******* 58 *******
# C
# B
#
# ******* 59 *******
# lehre
# E
#
# ******* 60 *******
# A
# A
#
# ******* 61 *******
# E
# B
#
# ******* 62 *******
# C
# B
#
# ******* 63 *******
# C
# B
#
# ******* 64 *******
# E
# B
#
# ******* 65 *******
# C
# A
#
# ******* 66 *******
# A
# C
#
# ******* 67 *******
# C
# B
#
# ******* 68 *******
# Berufsabschluss
# C
#
# ******* 69 *******
# A
# C
#
# ******* 70 *******
# Mittlere Reife
# C
#
# ******* 71 *******
# C
# C
#
# ******* 72 *******
# A
# A
#
# ******* 73 *******
# C
# B
#
# ******* 74 *******
# ausbildung
# E
#
# ******* 75 *******
# D
# B
#
# ******* 76 *******
# C
# B
#
# ******* 77 *******
# C
# B
#
# ******* 78 *******
# A
# E
#
# ******* 79 *******
# A
# E
#
# ******* 80 *******
# C
# B
#
# ******* 81 *******
# Berufabschluß
# C
#
# ******* 82 *******
# arbeitslos
# C
#
# ******* 83 *******
# B
# A
#
# ******* 84 *******
# A
# C
#
# ******* 85 *******
# Normale Lehre mit Abschluss
# C
#
# ******* 86 *******
# A
# E
#
# ******* 87 *******
# A
# A
#
# ******* 88 *******
# Realschule und Berufsausbildung
# A
#
# ******* 89 *******
# A
# B
#
# ******* 90 *******
# Mittlere Reife
# C
#
# ******* 91 *******
# A
# A
#
# ******* 92 *******
# A
# A
#
# ******* 93 *******
# Hauptschule
# C
#
# ******* 94 *******
# A
# A
#
# ******* 95 *******
# Hauptschulabschluss
# C
#
# ******* 96 *******
# A
# E
#
# ******* 97 *******
# Höhere Handelsschule Berufsausbildung
# C
#
# ******* 98 *******
# B
# E
#
# ******* 99 *******
# B
# E

# %% [markdown]
# there is too much inconsistency, as a general rule of thumb, we're going to trust our data, and only use the sup data where necessary (custom answers and NaN)

# %%
# replacing answers for q27 where appropriate
possible_options = ["A", "B", "C", "D", "E"]
pf_fr.q27 = [ans if ans in possible_options else pf_fr.q27_sup[i] for i, ans in enumerate(pf_fr.q27)]
pf_de.q27 = [ans if ans in possible_options else pf_de.q27_sup[i] for i, ans in enumerate(pf_de.q27)]

# %% [markdown]
# ### We need to recode the age group too

# %% [markdown]
# The categories do not exactly match ours, but they're similar enough, for the sake of the analysis we'll replace them with our categorisation. See the comparison below
#
#              PF            GM
# A-----------------[n/a]-----------------[<= 15]
#
# B--------------[18 - 24]--------------[16 - 25]
#
# C--------------[25 - 34]--------------[26 - 35]
#
# D--------------[35 - 44]--------------[36 - 45]
#
# E--------------[45 - 54]--------------[46 - 55]
#
# F----------------[> 54]----------------[>= 56]

# %% [markdown]
# As indicated by the chart above, we can convert the data without much loss of accurate information

# %%
pf_age_brackets = sorted(list(set(pf_fr.q24_sup)))
pf_age_brackets
# Out:
# ['18 - 24', '25 - 34', '35 - 44', '45 - 54', '> 54']

# %%
age_codes = ['B', 'C', 'D', 'E', 'F']

# %%
# creating recoding dict
age_dict_pf = {pf_age_brackets[i]:age_codes[i] for i in range(len(age_codes))}

# %%
# now converting the age column q24
pf_fr.q24 = [age_dict_pf[age] for age in pf_fr.q24_sup]
pf_de.q24 = [age_dict_pf[age] for age in pf_de.q24_sup]

# %%
# now we can drop the sup columns since we've encorporated them into the real qs
pf_fr.drop(['q24_sup', 'q27_sup'], axis = 1, inplace = True)
pf_de.drop(['q24_sup', 'q27_sup'], axis = 1, inplace = True)

# %%
# reordering the columns
pf_fr = pf_fr[sorted(pf_fr.columns)]
pf_de = pf_de[sorted(pf_fr.columns)]
