# %%
import pandas as pd
import os

# %%
# set data dir
data_dir = "../../AI_perception_survey_data/CN"

# %%
# get file name
fname = os.listdir(data_dir)

# %%
# load in the data
agg_data = pd.read_csv(os.path.join(data_dir, fname[0]), sep=',')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-688202d4f19c> in <module>()
#       1 # load in the data
# ----> 2 agg_data = pd.read_csv(os.path.join(data_dir, fname[0]), sep=',')
#
# ...

# %%
agg_data
# Out:
#                                                   第1页
# 0                                                 第2页
# 1                                 1.您如何评价您的人工智能技术的知识？
# 2                        2.关于人工智能的性质或者能力的阐述，以下哪些是错误的？
# 3                                     3.您是否使用过人工智能应用？
# 4                                                 第3页
# 5                              4.您如何评价人工智能技术今天对社会的影响？
# 6                                            5.十年之后呢？
# 7                                 6.您如何评价人工智能当今的影响范围？
# 8                                            7.十年之后呢？
# 9                                                 第4页
# 10                              8.您如何评价人工智能对您职业生涯的影响？
# 11                                           9.十年之后呢？
# 12      10.您的职业生涯中，哪些方面受益最多于人工智能应用？请从以下选项中选择，如果其他，请注明
# 13  11.您的职业生涯中，哪些方面受到最多人工智能应用的负面影响？请从以下选项中选择，如果其他，...
# 14                     12.您如何评价人工智能对您个人生活的影响？（职业生活之外）
# 15                                          13.十年之后呢？
# ...
